# %% [markdown]
# <a href="https://colab.research.google.com/github/Hemondj/Dat512Week3/blob/main/Pandas_cleaning_tools.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Data Cleaning and Pandas
#
# See Chapter 7 of "Python for Data Analysis" by Wes McKinney

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Detecting and dealing with missing data
#
# python uses both null and NaN
#
# in Pandas,  the convention is to use NaN to indicate missing data

# %% [markdown]
# ### Comment on dropping Na values
#
# There are times when it seems to okay to simply drop Nas,   if a variable has over 50% of the variables missing,  it may be simply useless
#
# But, in general,  we really want to know why data is missing before we remove it.
#
# If there are patterns or correlations in the missing data, that means something.
#
# Some ML tools can use Na values in the model,  such as GBMLight,   so they attempt to include the Na values as data input

# %%
stuff=['cat','dog','hamster',np.nan, 'aardvark']
stuff2=[1,2,None,3,4]

first_df=pd.DataFrame(list(zip(stuff,stuff2)),columns=['animal','flag'])

first_df.head()
# Out:
#      animal  flag
# 0       cat   1.0
# 1       dog   2.0
# 2   hamster   NaN
# 3       NaN   3.0
# 4  aardvark   4.0

# %%
first_df.isnull()
# Out:
#    animal   flag
# 0   False  False
# 1   False  False
# 2   False   True
# 3    True  False
# 4   False  False

# %%
#Question-  what is happeing here with NaN and null?  How do the detection functions isnull and isna seem to work

# %% [markdown]
# They are being treated as the same thing, both functions seem to check for Na and Null they work the same way

# %%
first_df.animal.isnull()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# Name: animal, dtype: bool

# %%
first_df.flag.isna()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# Name: flag, dtype: bool

# %%
first_df.animal.notnull()
# Out:
# 0     True
# 1     True
# 2     True
# 3    False
# 4     True
# Name: animal, dtype: bool

# %%
# Automatic removal of rows or columns with NA

# %%
from numpy import nan as NA

# note the aliasing of nan as NA,   this may be easy to read

data = pd.DataFrame([[1., 6.5, 3.], [1., NA, NA],[NA, NA, NA], [NA, 6.5, 3.]])
data
# Out:
#      0    1    2
# 0  1.0  6.5  3.0
# 1  1.0  NaN  NaN
# 2  NaN  NaN  NaN
# 3  NaN  6.5  3.0

# %%
data.dropna(how='all')
# Out:
#      0    1    2
# 0  1.0  6.5  3.0
# 1  1.0  NaN  NaN
# 3  NaN  6.5  3.0

# %%
data[4]=NA
data
data.dropna(axis=1, how='all')
# Out:
#      0    1    2
# 0  1.0  6.5  3.0
# 1  1.0  NaN  NaN
# 2  NaN  NaN  NaN
# 3  NaN  6.5  3.0

# %% [markdown]
# # look up pandas dropna,    what other options are there for how=?,    what is axis=1 doing?   What is the default axis?

# %% [markdown]
# any
#
# checks columns
#
# defalt is 0

# %%
df = pd.DataFrame(np.random.randn(7, 3))

df.iloc[:4, 1] = NA

df.iloc[:2, 2] = NA

df
# Out:
#           0         1         2
# 0  1.063656       NaN       NaN
# 1 -0.959323       NaN       NaN
# 2  1.853512       NaN -1.326196
# 3  0.822420       NaN  2.232801
# 4  0.530904 -0.508524  1.311515
# 5 -0.162607  1.651302 -0.926685
# 6  0.696418 -1.342438  0.616619

# %%
df.dropna(thresh=2)
# Out:
#           0         1         2
# 2  1.853512       NaN -1.326196
# 3  0.822420       NaN  2.232801
# 4  0.530904 -0.508524  1.311515
# 5 -0.162607  1.651302 -0.926685
# 6  0.696418 -1.342438  0.616619

# %% [markdown]
# # Filling in missing data
#
# imputing or filling in constants

# %%
df.fillna(0)
# Out:
#           0         1         2
# 0  1.063656  0.000000  0.000000
# 1 -0.959323  0.000000  0.000000
# 2  1.853512  0.000000 -1.326196
# 3  0.822420  0.000000  2.232801
# 4  0.530904 -0.508524  1.311515
# 5 -0.162607  1.651302 -0.926685
# 6  0.696418 -1.342438  0.616619

# %%
df.fillna(data.mean())
# Out:
#           0         1         2
# 0  1.063656  6.500000  3.000000
# 1 -0.959323  6.500000  3.000000
# 2  1.853512  6.500000 -1.326196
# 3  0.822420  6.500000  2.232801
# 4  0.530904 -0.508524  1.311515
# 5 -0.162607  1.651302 -0.926685
# 6  0.696418 -1.342438  0.616619

# %%
df.fillna({1:0.5,2.0:0})
# Out:
#           0         1         2
# 0  1.063656  0.500000  0.000000
# 1 -0.959323  0.500000  0.000000
# 2  1.853512  0.500000 -1.326196
# 3  0.822420  0.500000  2.232801
# 4  0.530904 -0.508524  1.311515
# 5 -0.162607  1.651302 -0.926685
# 6  0.696418 -1.342438  0.616619

# %%
df.fillna({1:data[1].mean(),2.0:data[2].mean()})
# Out:
#           0         1         2
# 0  1.063656  6.500000  3.000000
# 1 -0.959323  6.500000  3.000000
# 2  1.853512  6.500000 -1.326196
# 3  0.822420  6.500000  2.232801
# 4  0.530904 -0.508524  1.311515
# 5 -0.162607  1.651302 -0.926685
# 6  0.696418 -1.342438  0.616619

# %% [markdown]
# # # Question
# Explain what the previous two cells are doing
# Create a cell below that replaces Na with the median

# %% [markdown]
# each are filling in the columns 1 and 2 with specified numbers

# %% [markdown]
# ## dropping duplicate rows

# %%
data = pd.DataFrame({'k1': ['one', 'two'] * 3 + ['two'], 'k2': [1, 1, 2, 3, 3, 4, 4]})

# %%
data
# Out:
#     k1  k2
# 0  one   1
# 1  two   1
# 2  one   2
# 3  two   3
# 4  one   3
# 5  two   4
# 6  two   4

# %%
data.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6     True
# dtype: bool

# %%
np.sum(data.duplicated())
# Out:
# 1

# %%
data.drop_duplicates()
# Out:
#     k1  k2
# 0  one   1
# 1  two   1
# 2  one   2
# 3  two   3
# 4  one   3
# 5  two   4

# %% [markdown]
# ## Replacing values and Sentinels
#
# In many older systems, there are "sentinel" or "marker" values that indicate missing data,   common values used for this are 9999, 99999, -9999, "?", etc.
#
# In pf.read_csv(),  and probably many other read() operations, we can specify the values interpretted as Na
#
# na_values:  scalar, str, list-like, or dict, optional
#
# Additional strings to recognize as NA/NaN. If dict passed, specific per-column NA values. By default the following values are interpreted as NaN: ‘’, ‘#N/A’, ‘#N/A N/A’, ‘#NA’, ‘-1.#IND’, ‘-1.#QNAN’, ‘-NaN’, ‘-nan’, ‘1.#IND’, ‘1.#QNAN’, ‘<NA>’, ‘N/A’, ‘NA’, ‘NULL’, ‘NaN’, ‘n/a’, ‘nan’, ‘null’.

# %%
data = pd.Series([1., -999., 2., -999., -1000., 3.])

data
# Out:
# 0       1.0
# 1    -999.0
# 2       2.0
# 3    -999.0
# 4   -1000.0
# 5       3.0
# dtype: float64

# %%
data.replace(-999, np.nan)
# Out:
# 0       1.0
# 1       NaN
# 2       2.0
# 3       NaN
# 4   -1000.0
# 5       3.0
# dtype: float64

# %%
data.replace([-999, -1000], [np.nan, 0])
# Out:
# 0    1.0
# 1    NaN
# 2    2.0
# 3    NaN
# 4    0.0
# 5    3.0
# dtype: float64

# %% [markdown]
# # Altering Axis indexes

# %%
data = pd.DataFrame(np.arange(12).reshape((3, 4)),index=['Ohio', 'Colorado', 'New York'],columns=['one', 'two', 'three', 'four'])
data
# Out:
#           one  two  three  four
# Ohio        0    1      2     3
# Colorado    4    5      6     7
# New York    8    9     10    11

# %%
#Applying a transformation to indices

def trans(x):
    return( x[0:4].upper() )

data.index=data.index.map(trans)
data
# Out:
#       one  two  three  four
# OHIO    0    1      2     3
# COLO    4    5      6     7
# NEW     8    9     10    11

# %%
data.index
# Out:
# Index(['OHIO', 'COLO', 'NEW '], dtype='object')

# %%
 # This is a function I've been trying to find for a while, handy
# Notice that extra space in the index 'NEW '

data.rename(index={'NEW ': 'NY'},columns={'three': 'peekaboo'})
# Out:
#       one  two  peekaboo  four
# OHIO    0    1         2     3
# COLO    4    5         6     7
# NY      8    9        10    11

# %%
data.rename(index={'NEW ': 'NY'})
# Out:
#       one  two  three  four
# OHIO    0    1      2     3
# COLO    4    5      6     7
# NY      8    9     10    11

# %%
## Discretization and Binning of continuous data

# %%
ages = [20, 22, 25, 27, 21, 23, 37, 31, 61, 45, 41, 32]

#convert to categorical ranges

bins = [18, 25, 35, 60, 100]

cats = pd.cut(ages, bins)

cats
# Out:
# [(18, 25], (18, 25], (18, 25], (25, 35], (18, 25], ..., (25, 35], (60, 100], (35, 60], (35, 60], (25, 35]]
# Length: 12
# Categories (4, interval[int64, right]): [(18, 25] < (25, 35] < (35, 60] < (60, 100]]

# %%
cats.categories
# Out:
# IntervalIndex([(18, 25], (25, 35], (35, 60], (60, 100]], dtype='interval[int64, right]')

# %%
cats.codes
# Out:
# array([0, 0, 0, 1, 0, 0, 2, 1, 3, 2, 2, 1], dtype=int8)

# %%
ages
# Out:
# [20, 22, 25, 27, 21, 23, 37, 31, 61, 45, 41, 32]

# %%
pd.value_counts(cats)
# Out:
# (18, 25]     5
# (25, 35]     3
# (35, 60]     3
# (60, 100]    1
# dtype: int64

# %% [markdown]
# # when you create a categorizer,  where are the categories names? Where are the values for each specimen?

# %% [markdown]
# labels
#
# x

# %%
group_names = ['Youth', 'YoungAdult', 'MiddleAged', 'Senior']
pd.cut(ages, bins, labels=group_names)
# Out:
# ['Youth', 'Youth', 'Youth', 'YoungAdult', 'Youth', ..., 'YoungAdult', 'Senior', 'MiddleAged', 'MiddleAged', 'YoungAdult']
# Length: 12
# Categories (4, object): ['Youth' < 'YoungAdult' < 'MiddleAged' < 'Senior']

# %%
pd.value_counts(ages)
# Out:
# 20    1
# 22    1
# 25    1
# 27    1
# 21    1
# 23    1
# 37    1
# 31    1
# 61    1
# 45    1
# 41    1
# 32    1
# dtype: int64

# %% [markdown]
# # is this set up to indicate an ordered category?

# %% [markdown]
# Yes

# %% [markdown]
# ## Dividing data into equally spaced quintiles
#
# qcut produces a desired number of quintile categories

# %%
data = np.random.randn(1000)  # Normally distributed

cats = pd.qcut(data, 4)  # Cut into quartiles

cats
# Out:
# [(0.703, 3.496], (0.703, 3.496], (-0.00422, 0.703], (-0.685, -0.00422], (-3.651, -0.685], ..., (0.703, 3.496], (-0.685, -0.00422], (0.703, 3.496], (0.703, 3.496], (-0.00422, 0.703]]
# Length: 1000
# Categories (4, interval[float64, right]): [(-3.651, -0.685] < (-0.685, -0.00422] < (-0.00422, 0.703] <
#                                            (0.703, 3.496]]

# %%
pd.value_counts(cats)
# Out:
# (-3.651, -0.685]      250
# (-0.685, -0.00422]    250
# (-0.00422, 0.703]     250
# (0.703, 3.496]        250
# dtype: int64

# %% [markdown]
# ## Detecting and Filtering Outliers

# %%
data = pd.DataFrame(np.random.randn(1000, 4))

data.describe()
# Out:
#                  0            1            2            3
# count  1000.000000  1000.000000  1000.000000  1000.000000
# mean     -0.017206    -0.019095     0.010618     0.056183
# std       0.994521     0.982430     0.967542     1.032337
# min      -3.035654    -3.304624    -3.329033    -3.246024
# 25%      -0.662281    -0.724889    -0.559056    -0.688108
# 50%      -0.004471    -0.024369     0.024172     0.056370
# 75%       0.651479     0.647903     0.640252     0.691908
# max       2.898632     3.212209     3.528152     4.124580

# %%
# Detecting values with abs value over 3 from column 2

col = data[2]

col[np.abs(col) > 3]
# Out:
# 20     3.528152
# 961   -3.329033
# Name: 2, dtype: float64

# %%
data[(np.abs(data) > 3).any(1)]
# Out:
# <ipython-input-48-972b47795d6b>:1: FutureWarning: In a future version of pandas all arguments of DataFrame.any and Series.any will be keyword-only.
#   data[(np.abs(data) > 3).any(1)]
#             0         1         2         3
# 20  -0.605934  1.796865  3.528152  2.243342
# 754 -0.581926  1.070384  0.402524  3.066722
# 795 -0.891208 -1.231674  0.641196 -3.246024
# 815 -3.035654  0.557693 -2.176769 -0.487217
# 852  0.044301  3.212209 -0.351916 -0.549835
# 853  0.536098 -3.304624  0.899868  0.569386
# 951 -0.301200 -2.420654 -0.893127  4.124580
# 961 -0.719873  0.711447 -3.329033 -1.062420
# 982  0.944623  0.203475 -0.618833  3.124185
