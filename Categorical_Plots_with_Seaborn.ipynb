# %% [markdown]
# <a href="https://colab.research.google.com/github/Hemondj/Dat512Week3/blob/main/Categorical_Plots_with_Seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Categorical plotting using Seaborn
#
# https://seaborn.pydata.org/tutorial/categorical.html
#
# We've seen a number of plots meant to show the characteristics of continuouos variables in exploratory data analysis,  these are few meant for examining
# categorical variables

# %%
import seaborn as sns
import pandas as pd
import numpy as np

# %%
sns.set_theme(style="darkgrid")
tips = sns.load_dataset("tips")
ax = sns.pointplot(x="time", y="total_bill", data=tips)

# %%
# tips is Seaborn example data set,  it looks at tips are a restaurant
# this is back when smoking was legal in restaurants

tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ## Question,  what is this plot showing us?  The dots are the means, the bar height looks like a range measure-it is described as an error bar
#
# Check the min and max total bill for dinner and lunch
#
# Also check the standard deviation for the dinner and lunch tips

# %%
ax = sns.pointplot(x="time", y="total_bill", hue="smoker",data=tips)

# %%
#add a bit of an offset
ax = sns.pointplot(x="time", y="total_bill", hue="smoker",data=tips, dodge=0.03)

# %%
# bootstrap resamplign to estimate the confidence intervals

# this is using a bootstrap method instead of the standard estimater for error in the mean.  If the distribution was highly non-normal the bookstrap method may be more effective

ax = sns.pointplot(x="time", y="total_bill", hue="smoker",data=tips, dodge=0.03,n_boot=100)

# %%
# more plot control

ax = sns.pointplot(x="time", y="total_bill", hue="smoker",
                   data=tips,
                   markers=["o", "x"],
                   linestyles=["-", "--"])

# %%
ax = sns.pointplot(x="day", y="tip", data=tips, capsize=.2,hue="smoker")

# %% [markdown]
# Notice the shift here in the impact of smokers on tips.   This plot is showing both lunch and dinner,  so there is something complicated going on here
# related to the number of smokers and the ratio of lunches per day to the dinners per day

# %%
g = sns.catplot(x="sex", y="total_bill",
                hue="smoker", col="time",
                data=tips, kind="point",
                dodge=True,
                height=4, aspect=.7);

# %%
g = sns.catplot(x="day", y="total_bill",
                hue="smoker", col="time",
                data=tips, kind="point",
                dodge=True,
                height=4, aspect=.7);

# %% [markdown]
# #Question  Explain what this plot tells us about the mixture of smakers,  lunch/Dinner ratios and total bills, as well as day of the week

# %% [markdown]
# # Barplots

# %%
sns.set_theme(style="whitegrid")
ax = sns.barplot(x="day", y="total_bill", data=tips)

# %%
ax = sns.barplot(x="day", y="total_bill", hue="sex", data=tips)

# %% [markdown]
# #Question
#
# The above plot shows the impact of gender on the total bill.
#
# alter this to see the impact of lunch and dinner on the total bill

# %%
ax = sns.barplot(x="time", y="total_bill", hue="sex", data=tips)

# %%
# another alternative
ax = sns.barplot(x="tip", y="day", data=tips)

# %%
# show the plot with the standard deviation, rather than the uncertainty in the mean
ax = sns.barplot(x="day", y="tip", data=tips, ci="sd",capsize=0.1)
# Out:
# <ipython-input-15-0e5754801328>:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   ax = sns.barplot(x="day", y="tip", data=tips, ci="sd",capsize=0.1)

# %%
ax = sns.barplot(x="size", y="total_bill", data=tips,palette="Blues_d")
# Out:
# <ipython-input-16-8a887d3d09f2>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x="size", y="total_bill", data=tips,palette="Blues_d")

# %%
g = sns.catplot(x="sex", y="total_bill",
                hue="smoker", col="time",
                data=tips, kind="bar",
                height=4, aspect=.7);

# %% [markdown]
# ## Count Plots

# %%
# using the classic titanic data set

sns.set_theme(style="darkgrid")
titanic = sns.load_dataset("titanic")

# %%
# we have a lot of categorical variables here,   survived, passenger class, sex, embarked, class, who, deck, embarktown, alone
# making this a nice example for working with categorical information

titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
# counts by passenger class

ax = sns.countplot(x="class", hue="who", data=titanic)

# %%
# here's the cool one...

g = sns.catplot(x="class", hue="who", col="survived",
                data=titanic, kind="count",
                height=4, aspect=.7);

# %% [markdown]
# # Homework
#
# One of the implications of the tips data set is that smokers have higher restaurant bills,  so maybe smoking in restaurants is econoomically desirable
#
# However,  there may be evidence that exposure to smoke in the work place can lead to increase heart disease,   I pulled table 3 out of the published
# Cardia Study on this issue
#
# The data is in the Cardia Table 3 pdf file.  You will have to manually extract this data, problably by entering it into an Excel file, by cutting and pasting
# from the pdf.  From there,  you can load it into python and plot various aspects of that data table
#
# Use the data and graphs to make an argument that smoke exposure does or does not effect heart disease rates for employees

# %% [markdown]
# https://www.ahajournals.org/doi/10.1161/CIRCULATIONAHA.117.032302

# %% [markdown]
# Longitudinal Associations of Smoke-Free Policies and Incident Cardiovascular Disease
# CARDIA Study
# Stephanie L. Mayne, Rachel Widome, Allison J. Carroll, Pamela J. Schreiner, Penny Gordon-Larsen, David R. JacobsJr, and Kiarri N. Kershaw
